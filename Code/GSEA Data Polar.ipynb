# %% [markdown]
# # GSEA DATA

# %%
# %pwd
# %matplotlib inline

import pandas as pd
import numpy as np
import csv
import pickle
from imblearn.over_sampling import SMOTE

#Random Number
r = 42

# %% [markdown]
# ## Load Data

# %%
#Load Expression and Metadata
df = pd.read_csv('Output/expression_matrix.txt', index_col=0).T
dfanno = pd.read_csv('Output/metadata.txt', index_col=0, header=None, squeeze = True)

#Load Genes
genes = pd.read_csv('Output/2000_ranked_genes.txt', squeeze=True, header=None)
genes
# Out:
# 0          SMOX / 11741507_a_at
# 1         TMCC2 / 11721929_x_at
# 2         RBM38 / 11715594_a_at
# 3       CXORF22 / 11758541_s_at
# 4         SUMF1 / 11720732_a_at
#                  ...
# 1995       MEST / 11758268_s_at
# 1996     MRPS10 / 11758291_s_at
# 1997       GJB6 / 11733922_s_at
# 1998      CYTH3 / 11757447_s_at
# 1999       NOS2 / 11752035_a_at
# Name: 0, Length: 2000, dtype: object

# %% [markdown]
# ## Select Top 2000 Genes

# %%
#Choose Genes
df = df[genes]
df = df.astype(float)
df
# Out:
#             SMOX / 11741507_a_at  TMCC2 / 11721929_x_at  \
# 116_S_1249              0.807886              -0.941795
# 037_S_4410             -2.097621              -0.679543
# 006_S_4153             -0.864382              -0.737287
# 116_S_1232              1.119981               0.930056
# 099_S_4205             -1.440825              -0.643454
# ...                          ...                    ...
# 009_S_2381              0.834670               1.567640
# 053_S_4557              0.339744              -0.248873
# 073_S_4300              1.281851              -0.268121
# 041_S_4014             -1.105440              -0.330677
# 007_S_0101             -0.230876              -0.958637
#
#             RBM38 / 11715594_a_at  CXORF22 / 11758541_s_at  \
# 116_S_1249              -0.165369                -1.571180
# 037_S_4410              -1.102886                 1.949596
# 006_S_4153              -0.249376                 0.076363
# 116_S_1232               1.533250                 1.580968
# 099_S_4205              -1.400271                -1.112275
# ...                           ...                      ...
# 009_S_2381               1.212343                -0.848969
# 053_S_4557               0.362194                 0.113978
# 073_S_4300               1.397159                 0.309577
# 041_S_4014              -0.061201                 0.271961
# 007_S_0101              -1.479237                -0.818877
#
#             SUMF1 / 11720732_a_at  TRIM10 / 11758611_s_at  \
# 116_S_1249              -1.277643                0.191825
# 037_S_4410              -1.347309               -1.900826
# 006_S_4153              -0.731320               -0.791592
# 116_S_1232               0.698655                1.524941
# 099_S_4205              -0.243661               -1.761131
# ...                           ...                     ...
# 009_S_2381              -0.390326                0.943958
# 053_S_4557              -0.995315                1.017968
# 073_S_4300              -0.082331                1.332514
# 041_S_4014               0.566658                0.065081
# 007_S_0101              -0.005332               -1.416982
#
#             SLC6A13 / 11759654_a_at  MKRN3 / 11736971_at  OMG / 11730727_at  \
# 116_S_1249                 0.166623             0.064653           2.393200
# 037_S_4410                -0.404871             1.290969           1.777766
# 006_S_4153                 0.752405             0.216220          -0.175261
# 116_S_1232                -0.258426             0.014131          -1.214029
# 099_S_4205                -0.865638             2.214151           2.581744
# ...                             ...                  ...                ...
# 009_S_2381                -0.362009            -0.119065           1.414909
# 053_S_4557                 0.009462            -1.230557          -0.669743
# 073_S_4300                -0.512026            -0.766670           0.194712
# 041_S_4014                -0.136983            -0.348712          -0.883188
# 007_S_0101                -0.583463            -1.313230          -0.861844
#
#             RIPK2 / 11724236_a_at  ...  SMG8 / 11720182_at  \
# 116_S_1249               1.705883  ...            0.704779
# 037_S_4410               1.349050  ...            0.788917
# 006_S_4153              -0.643264  ...           -0.664376
# 116_S_1232              -0.666392  ...            0.417945
# 099_S_4205              -0.035327  ...            0.207600
# ...                           ...  ...                 ...
# 009_S_2381              -0.692824  ...           -4.179049
# 053_S_4557               0.456969  ...           -0.109830
# 073_S_4300               1.616675  ...            0.238196
# 041_S_4014               0.281857  ...           -2.557480
# 007_S_0101               1.428346  ...           -0.228388
#
#             ARHGEF2 / 11749038_a_at  OR52E8 / 11738498_at  \
# 116_S_1249                -1.363409              0.568343
# 037_S_4410                -1.117208              1.997113
# 006_S_4153                 0.578845             -0.042758
# 116_S_1232                 0.152096              2.694284
# 099_S_4205                 0.288875             -0.998140
# ...                             ...                   ...
# 009_S_2381                 0.119269             -0.628037
# 053_S_4557                -0.520854             -0.731321
# 073_S_4300                -1.215688             -1.230530
# 041_S_4014                 0.600729              0.008885
# 007_S_0101                -0.230883             -0.068579
#
#             ERF / 11718263_a_at  HOXB1 / 11759812_at  MEST / 11758268_s_at  \
# 116_S_1249            -1.845089             0.188231             -0.341429
# 037_S_4410            -1.152794            -0.472398             -0.581685
# 006_S_4153            -0.239555             0.083671             -0.201745
# 116_S_1232            -0.077529             1.804158              1.183916
# 099_S_4205            -0.013700             0.121693              0.396101
# ...                         ...                  ...                   ...
# 009_S_2381             0.452739             1.162540             -0.609621
# 053_S_4557             0.113957             0.164467              0.731341
# 073_S_4300            -0.607797             0.501911              0.787215
# 041_S_4014            -0.377032             2.003773             -0.011775
# 007_S_0101             0.379091             0.311802              0.038511
#
#             MRPS10 / 11758291_s_at  GJB6 / 11733922_s_at  \
# 116_S_1249                0.406144              0.614945
# 037_S_4410                0.779213              0.934333
# 006_S_4153                1.372198             -0.981990
# 116_S_1232               -1.247145             -0.554336
# 099_S_4205               -0.587400             -1.144391
# ...                            ...                   ...
# 009_S_2381                0.900952              0.322625
# 053_S_4557                0.013439             -0.310736
# 073_S_4300               -0.744482              0.328038
# 041_S_4014                1.254386              1.389053
# 007_S_0101               -0.878002              1.026359
#
#             CYTH3 / 11757447_s_at  NOS2 / 11752035_a_at
# 116_S_1249               0.618424             -1.625951
# 037_S_4410               1.302728             -1.972464
# 006_S_4153               1.194465             -0.361822
# 116_S_1232              -0.235424             -0.483743
# 099_S_4205               1.541724             -0.926509
# ...                           ...                   ...
# 009_S_2381              -0.163929              1.178234
# 053_S_4557               0.710345              1.531164
# 073_S_4300               0.291592             -0.393906
# 041_S_4014              -2.306719              0.196449
# 007_S_0101              -1.761319              1.223153
#
# [744 rows x 2000 columns]

# %% [markdown]
# ## SMOTE Oversampling

# %%
#Variables and Acutal
feature_list = list(df.columns)
print(dfanno.value_counts())

#Oversampling
df, dfanno = SMOTE(random_state=r, n_jobs=-1).fit_resample(df, dfanno)
print(dfanno.value_counts())
# Out:
# CN      260
# LMCI    226
# EMCI    215
# AD       43
# Name: 1, dtype: int64
# EMCI    260
# CN      260
# LMCI    260
# AD      260
# Name: 1, dtype: int64

# %% [markdown]
# ## Sort

# %%
df = df.T
df
# Out:
#                              0         1         2         3         4     \
# SMOX / 11741507_a_at     0.807886 -2.097621 -0.864382  1.119981 -1.440825
# TMCC2 / 11721929_x_at   -0.941795 -0.679543 -0.737287  0.930056 -0.643454
# RBM38 / 11715594_a_at   -0.165369 -1.102886 -0.249376  1.533250 -1.400271
# CXORF22 / 11758541_s_at -1.571180  1.949596  0.076363  1.580968 -1.112275
# SUMF1 / 11720732_a_at   -1.277643 -1.347309 -0.731320  0.698655 -0.243661
# ...                           ...       ...       ...       ...       ...
# MEST / 11758268_s_at    -0.341429 -0.581685 -0.201745  1.183916  0.396101
# MRPS10 / 11758291_s_at   0.406144  0.779213  1.372198 -1.247145 -0.587400
# GJB6 / 11733922_s_at     0.614945  0.934333 -0.981990 -0.554336 -1.144391
# CYTH3 / 11757447_s_at    0.618424  1.302728  1.194465 -0.235424  1.541724
# NOS2 / 11752035_a_at    -1.625951 -1.972464 -0.361822 -0.483743 -0.926509
#
#                              5         6         7         8         9     \
# SMOX / 11741507_a_at     0.860290 -0.941241  0.555183  1.505441  0.533057
# TMCC2 / 11721929_x_at   -0.020305 -0.953825  0.829005 -0.501501 -0.604958
# RBM38 / 11715594_a_at    0.726784 -0.975196  1.261067  0.750306  0.006005
# CXORF22 / 11758541_s_at -1.029522 -0.194466 -0.397588  0.964080  0.527744
# SUMF1 / 11720732_a_at   -1.424307  0.221997 -0.492990  0.188998  0.163331
# ...                           ...       ...       ...       ...       ...
# MEST / 11758268_s_at     0.312291  1.200678  1.792937 -0.654320 -0.084411
# MRPS10 / 11758291_s_at   0.123396 -0.143643 -0.512786 -1.522038  0.771359
# GJB6 / 11733922_s_at     0.008651  0.625772 -1.323031  0.306385  0.885613
# CYTH3 / 11757447_s_at    0.602082 -0.078136  1.088245  0.865591  0.863548
# NOS2 / 11752035_a_at    -0.528661 -0.239901 -0.066644  2.897963  1.922595
#
#                          ...      1030      1031      1032      1033  \
# SMOX / 11741507_a_at     ... -0.340778  1.454268 -0.221489 -0.535720
# TMCC2 / 11721929_x_at    ... -0.319962  0.424352  0.859460  0.682132
# RBM38 / 11715594_a_at    ... -0.014997  0.637781  1.045923  0.816362
# CXORF22 / 11758541_s_at  ... -1.217127  3.856393  0.100287  1.624328
# SUMF1 / 11720732_a_at    ... -1.741639  0.999676 -0.831184  0.800618
# ...                      ...       ...       ...       ...       ...
# MEST / 11758268_s_at     ... -0.168221  4.060574 -0.628740 -0.310039
# MRPS10 / 11758291_s_at   ... -0.215190 -2.589472  1.069344 -0.450999
# GJB6 / 11733922_s_at     ... -0.441502 -0.645649  0.153210  0.732842
# CYTH3 / 11757447_s_at    ... -0.476463 -0.803385 -0.234879  1.108332
# NOS2 / 11752035_a_at     ... -0.870561 -0.110034  0.425454 -0.791788
#
#                              1034      1035      1036      1037      1038  \
# SMOX / 11741507_a_at     0.781523 -1.008846  0.755560 -1.350559  0.658684
# TMCC2 / 11721929_x_at    0.390739 -0.092731  0.393596 -0.565275 -0.459336
# RBM38 / 11715594_a_at    0.560388 -1.138785  0.563743  0.400354  0.872278
# CXORF22 / 11758541_s_at -1.197034  0.095782 -1.176729 -1.356769  0.303156
# SUMF1 / 11720732_a_at   -0.446848 -0.115051 -0.407658 -0.155828 -0.418780
# ...                           ...       ...       ...       ...       ...
# MEST / 11758268_s_at     1.032032  0.024361  1.062796 -0.353163 -0.947126
# MRPS10 / 11758291_s_at   0.744186  1.059798  0.772804  0.098979 -0.101742
# GJB6 / 11733922_s_at    -0.345829  0.482597 -0.339107 -0.144384 -0.628022
# CYTH3 / 11757447_s_at   -0.184533  1.052919 -0.222465  0.798724  0.350076
# NOS2 / 11752035_a_at    -1.013179  0.235942 -1.006252  0.190032 -0.204485
#
#                              1039
# SMOX / 11741507_a_at    -0.315920
# TMCC2 / 11721929_x_at    0.349047
# RBM38 / 11715594_a_at    0.168388
# CXORF22 / 11758541_s_at -0.669320
# SUMF1 / 11720732_a_at   -1.168726
# ...                           ...
# MEST / 11758268_s_at    -0.217759
# MRPS10 / 11758291_s_at  -0.273829
# GJB6 / 11733922_s_at    -0.123261
# CYTH3 / 11757447_s_at    0.087201
# NOS2 / 11752035_a_at     0.382433
#
# [2000 rows x 1040 columns]

# %%
#Sort AD first
dfanno = dfanno.replace('AD', 0).replace('LMCI', 11).replace('EMCI', 11).replace('CN', 3)
dfanno = dfanno.sort_values()

dfanno = dfanno[dfanno<4]

#Binarize
dfanno = dfanno.replace(0, 0).replace(1, 1).replace(1, 2).replace(3, 1)

df = df[dfanno.index]

# %%
df
# Out:
#                               858       900       901       789       788  \
# SMOX / 11741507_a_at    -0.534207 -0.836481 -1.131483 -1.668093  0.393497
# TMCC2 / 11721929_x_at   -1.467301 -0.871943 -0.922696 -0.478792 -0.745354
# RBM38 / 11715594_a_at   -0.390813 -2.118132 -0.923891 -1.038733 -0.061991
# CXORF22 / 11758541_s_at -0.645587  0.210253  0.971347  0.975164  0.052644
# SUMF1 / 11720732_a_at   -1.672771 -0.096621 -0.446848 -0.489783 -2.057086
# ...                           ...       ...       ...       ...       ...
# MEST / 11758268_s_at     0.792757  0.045632  0.098960 -0.393673 -0.956085
# MRPS10 / 11758291_s_at   0.682710  0.513949  0.548920  0.074977  0.325943
# GJB6 / 11733922_s_at    -1.086974 -0.731784 -1.358596 -0.604160  1.664739
# CYTH3 / 11757447_s_at    0.791200  0.558442 -0.513730 -0.181360  1.629484
# NOS2 / 11752035_a_at    -0.707562 -0.270439 -0.005376  0.267839  0.489186
#
#                               902       787       786       903       899  \
# SMOX / 11741507_a_at    -0.777390 -1.688704 -0.011357 -1.364594 -0.733269
# TMCC2 / 11721929_x_at   -0.687640 -0.148263 -0.834096 -1.203366 -0.168416
# RBM38 / 11715594_a_at   -0.186392  1.071192 -0.215659 -0.958510 -0.447204
# CXORF22 / 11758541_s_at  0.322482  0.724388 -0.194835  1.576400 -0.103648
# SUMF1 / 11720732_a_at   -0.949213 -0.454610 -1.688837 -1.634364  0.774337
# ...                           ...       ...       ...       ...       ...
# MEST / 11758268_s_at    -0.277664 -0.743874 -0.692912 -0.568392 -0.489488
# MRPS10 / 11758291_s_at  -0.789877 -0.248948 -0.146758 -0.009560 -1.957214
# GJB6 / 11733922_s_at    -0.771049 -0.053875  0.996943 -2.286669 -0.331469
# CYTH3 / 11757447_s_at   -0.697549  0.127242  0.733522  0.414157 -0.132509
# NOS2 / 11752035_a_at     1.252800 -0.533059  0.089390 -0.902049  1.755799
#
#                          ...       199       256       201       257  \
# SMOX / 11741507_a_at     ...  0.727533 -0.239028 -1.572417  0.168558
# TMCC2 / 11721929_x_at    ...  1.796208  0.266006  0.203451  0.643745
# RBM38 / 11715594_a_at    ... -0.355225  0.362194 -2.275622  0.506686
# CXORF22 / 11758541_s_at  ...  0.783527  2.024827  1.325185  0.347192
# SUMF1 / 11720732_a_at    ... -0.206995  0.500659  0.713322  0.566658
# ...                      ...       ...       ...       ...       ...
# MEST / 11758268_s_at     ... -1.162769  0.351402  2.597515 -0.268793
# MRPS10 / 11758291_s_at   ...  0.429706 -1.494549 -0.100446  0.637840
# GJB6 / 11733922_s_at     ... -1.041537  0.598705 -0.354043  1.069666
# CYTH3 / 11757447_s_at    ... -1.422231  1.345625  1.445717 -0.490761
# NOS2 / 11752035_a_at     ... -0.490160 -1.054847 -0.323320 -1.119016
#
#                               207       222       221       255       204  \
# SMOX / 11741507_a_at    -0.551122 -0.346165 -0.814307 -0.070171 -0.080652
# TMCC2 / 11721929_x_at   -0.496689  0.472920 -0.609770  0.533070 -0.400450
# RBM38 / 11715594_a_at   -0.395548 -1.507799 -1.306183  0.352113  0.311790
# CXORF22 / 11758541_s_at -0.284743  0.287008 -1.458335 -0.232081 -0.284743
# SUMF1 / 11720732_a_at    0.053333 -1.570971  2.168963  0.401660  0.511659
# ...                           ...       ...       ...       ...       ...
# MEST / 11758268_s_at     1.569443  0.815152 -0.699019 -1.017498 -1.051022
# MRPS10 / 11758291_s_at   1.144429  0.629985  0.044855 -1.156822 -0.131862
# GJB6 / 11733922_s_at     1.767987 -1.793992 -0.245776  2.590815 -1.009057
# CYTH3 / 11757447_s_at    0.301806  2.512005 -0.878874 -0.145545 -0.325302
# NOS2 / 11752035_a_at     0.921558 -0.708334  0.478792  0.786803 -0.201399
#
#                               227
# SMOX / 11741507_a_at     0.254733
# TMCC2 / 11721929_x_at    1.596512
# RBM38 / 11715594_a_at    0.918319
# CXORF22 / 11758541_s_at -1.157414
# SUMF1 / 11720732_a_at    1.013983
# ...                           ...
# MEST / 11758268_s_at    -0.905751
# MRPS10 / 11758291_s_at  -0.775899
# GJB6 / 11733922_s_at    -0.061722
# CYTH3 / 11757447_s_at   -2.141261
# NOS2 / 11752035_a_at    -0.246318
#
# [2000 rows x 520 columns]

# %%
dfanno
# Out:
# 858    0
# 900    0
# 901    0
# 789    0
# 788    0
#       ..
# 222    1
# 221    1
# 255    1
# 204    1
# 227    1
# Name: 1, Length: 520, dtype: int64

# %%
dfanno.value_counts()
# Out:
# 1    260
# 0    260
# Name: 1, dtype: int64

# %%
df.index = pd.MultiIndex.from_tuples( df.index.str.split(' / ').tolist(), names=['Name', 'Description'])
df
# Out:
#                             858       900       901       789       788  \
# Name    Description
# SMOX    11741507_a_at -0.534207 -0.836481 -1.131483 -1.668093  0.393497
# TMCC2   11721929_x_at -1.467301 -0.871943 -0.922696 -0.478792 -0.745354
# RBM38   11715594_a_at -0.390813 -2.118132 -0.923891 -1.038733 -0.061991
# CXORF22 11758541_s_at -0.645587  0.210253  0.971347  0.975164  0.052644
# SUMF1   11720732_a_at -1.672771 -0.096621 -0.446848 -0.489783 -2.057086
# ...                         ...       ...       ...       ...       ...
# MEST    11758268_s_at  0.792757  0.045632  0.098960 -0.393673 -0.956085
# MRPS10  11758291_s_at  0.682710  0.513949  0.548920  0.074977  0.325943
# GJB6    11733922_s_at -1.086974 -0.731784 -1.358596 -0.604160  1.664739
# CYTH3   11757447_s_at  0.791200  0.558442 -0.513730 -0.181360  1.629484
# NOS2    11752035_a_at -0.707562 -0.270439 -0.005376  0.267839  0.489186
#
#                             902       787       786       903       899  ...  \
# Name    Description                                                      ...
# SMOX    11741507_a_at -0.777390 -1.688704 -0.011357 -1.364594 -0.733269  ...
# TMCC2   11721929_x_at -0.687640 -0.148263 -0.834096 -1.203366 -0.168416  ...
# RBM38   11715594_a_at -0.186392  1.071192 -0.215659 -0.958510 -0.447204  ...
# CXORF22 11758541_s_at  0.322482  0.724388 -0.194835  1.576400 -0.103648  ...
# SUMF1   11720732_a_at -0.949213 -0.454610 -1.688837 -1.634364  0.774337  ...
# ...                         ...       ...       ...       ...       ...  ...
# MEST    11758268_s_at -0.277664 -0.743874 -0.692912 -0.568392 -0.489488  ...
# MRPS10  11758291_s_at -0.789877 -0.248948 -0.146758 -0.009560 -1.957214  ...
# GJB6    11733922_s_at -0.771049 -0.053875  0.996943 -2.286669 -0.331469  ...
# CYTH3   11757447_s_at -0.697549  0.127242  0.733522  0.414157 -0.132509  ...
# NOS2    11752035_a_at  1.252800 -0.533059  0.089390 -0.902049  1.755799  ...
#
#                             199       256       201       257       207  \
# Name    Description
# SMOX    11741507_a_at  0.727533 -0.239028 -1.572417  0.168558 -0.551122
# TMCC2   11721929_x_at  1.796208  0.266006  0.203451  0.643745 -0.496689
# RBM38   11715594_a_at -0.355225  0.362194 -2.275622  0.506686 -0.395548
# CXORF22 11758541_s_at  0.783527  2.024827  1.325185  0.347192 -0.284743
# SUMF1   11720732_a_at -0.206995  0.500659  0.713322  0.566658  0.053333
# ...                         ...       ...       ...       ...       ...
# MEST    11758268_s_at -1.162769  0.351402  2.597515 -0.268793  1.569443
# MRPS10  11758291_s_at  0.429706 -1.494549 -0.100446  0.637840  1.144429
# GJB6    11733922_s_at -1.041537  0.598705 -0.354043  1.069666  1.767987
# CYTH3   11757447_s_at -1.422231  1.345625  1.445717 -0.490761  0.301806
# NOS2    11752035_a_at -0.490160 -1.054847 -0.323320 -1.119016  0.921558
#
#                             222       221       255       204       227
# Name    Description
# SMOX    11741507_a_at -0.346165 -0.814307 -0.070171 -0.080652  0.254733
# TMCC2   11721929_x_at  0.472920 -0.609770  0.533070 -0.400450  1.596512
# RBM38   11715594_a_at -1.507799 -1.306183  0.352113  0.311790  0.918319
# CXORF22 11758541_s_at  0.287008 -1.458335 -0.232081 -0.284743 -1.157414
# SUMF1   11720732_a_at -1.570971  2.168963  0.401660  0.511659  1.013983
# ...                         ...       ...       ...       ...       ...
# MEST    11758268_s_at  0.815152 -0.699019 -1.017498 -1.051022 -0.905751
# MRPS10  11758291_s_at  0.629985  0.044855 -1.156822 -0.131862 -0.775899
# GJB6    11733922_s_at -1.793992 -0.245776  2.590815 -1.009057 -0.061722
# CYTH3   11757447_s_at  2.512005 -0.878874 -0.145545 -0.325302 -2.141261
# NOS2    11752035_a_at -0.708334  0.478792  0.786803 -0.201399 -0.246318
#
# [2000 rows x 520 columns]

# %% [markdown]
# ## Create CLS File

# %%
#CLS file
f = open('GSEA/Diagnosis_polar.cls', 'w')
f.write(str(dfanno.size)+' 2 1\n# AD CTL\n'+' '.join(map(str, dfanno)))
f.close()

# %% [markdown]
# ## Create Gene Expression Matrix

# %%
df.to_csv('GSEA/Genes_polar.txt', quoting=csv.QUOTE_MINIMAL, sep="\t")
